# %%
import numpy as np
from skimage.io import imread, imshow, imread_collection, concatenate_images
import matplotlib.pyplot as plt
from skimage.transform import resize
from skimage.segmentation import expand_labels

# %%
image = imread('./examples/Image10.png', as_gray=True)

# %%
image.shape
# Out:
# (480, 640)

# %%
image = np.expand_dims(resize(image, image.shape, mode='constant', preserve_range=True), axis=-1)

# %%
image.shape
# Out:
# (480, 640, 1)

# %%
image

# %%
plt.figure(figsize=(30, 15))
plt.imshow(image)
plt.show()

# %%
expanded_image = expand_labels(image, distance=1)

# %%
plt.figure(figsize=(30, 15))
plt.imshow(image)
plt.show()
# Out:
# /home/duy/anaconda3/envs/python37/lib/python3.7/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# /home/duy/anaconda3/envs/python37/lib/python3.7/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
