# %%
from utils import data_loader
import numpy as np
from skimage.io import imread
from skimage.transform import resize
import matplotlib.pyplot as plt
# Out:
# 2022-10-09 16:55:10.433186: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
mask = np.zeros((480, 640))
mask_ = imread('./datasets/mini_data/train/masks/image-1-000253.png', as_gray=True)
mask, points = data_loader.mapping_rescale_dot(mask, mask_)

# %%
points
# Out:
# array([[238, 296],
#        [245, 352],
#        [256, 275],
#        [258, 234],
#        [258, 368],
#        [269, 261],
#        [278, 389],
#        [280, 222],
#        [288, 462],
#        [302, 327],
#        [302, 386],
#        [309, 224],
#        [332, 191],
#        [356, 108],
#        [369, 129],
#        [373, 350],
#        [400, 132],
#        [408, 280],
#        [461, 358]])

# %%
mask_illusion = data_loader.dot_illusion(ground_truth_shape=mask.shape, points=points, gap_spaces=(10,5))
density_map_spread = data_loader.gaussian_filter_density(mask_illusion, fixed_sigma=10)

# %%
np.sum(density_map_spread)
# Out:
# 18.95098

# %%
plt.figure(figsize=(20, 10))
plt.imshow(mask_illusion, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.imshow(density_map_spread, cmap='gray')
plt.show()

# %%
np.sum(mask_illusion)
# Out:
# 19.0

# %%
np.sum(density_map_spread)
# Out:
# 18.95098
